# %%
import sys
import collections
from collections import Counter

import datetime
from datetime import datetime, timedelta, timezone
import dateutil.parser

from collections import defaultdict

import pandas as pd
import seaborn as sns
pd.options.display.max_rows = 999

import pydent
from pydent import AqSession, models
from pydent.models import Sample, Item, Plan

sys.path.append("../ext-plan-pydent")
from plans import ExternalPlan

# %%
filename = 'config.yml'

with open(filename, 'r') as f:
    config = yaml.load(f)

login = config['aquarium'][aq_instance]

session = AqSession(
    login['username'],
    login['password'],
    login['url']
)

me = session.User.where({'login': login['username']})[0]
print('Logged in as %s\n' % me.name)
    
session = ExternalPlan.create_session("production")
# Out:
# Logged in as Devin Strickland

# %% [markdown]
# ### Get all Operations from a single month window

# %%
year = 2018
month = 11

month_start = datetime(year, month, 1, tzinfo=timezone(-timedelta(hours=7)))
month_end = datetime(year, month + 1, 1, tzinfo=timezone(-timedelta(hours=7)))

window_ops = session.Operation.where("updated_at >= '{}' AND updated_at < '{}'".format(month_start, month_end))
print("{} Operations found between {} and {}.".format(len(window_ops), month_start, month_end))
# Out:
# 2018-11-01 00:00:00-07:00 Operations found between 2018-12-01 00:00:00-07:00 and 4529.

# %% [markdown]
# ### Get PlanAssociations for those Operations

# %%
window_op_ids = [op.id for op in window_ops]
window_plan_associations = session.PlanAssociation.where({"operation_id": window_op_ids})
print("{} PlanAssociations found for {} Operations.".format(len(window_plan_associations), len(window_ops)))
# Out:
# 4529 PlanAssociations found for 4529 Operations.

# %% [markdown]
# ### Get Plans for those PlanAssociations that are also for the DARPA budget

# %%
budget_name = "DARPA"
darpa_budget = session.Budget.find_by_name(budget_name)
window_plan_ids = [pa.plan_id for pa in window_plan_associations]
window_darpa_plans = session.Plan.where({"budget_id": darpa_budget.id, "id": window_plan_ids})
print("{} Plans found for {} between {} and {}.".format(len(window_darpa_plans), budget_name, month_start, month_end))
# Out:
# 125 Plans found for DARPA between 2018-11-01 00:00:00-07:00 and 2018-12-01 00:00:00-07:00.

# %% [markdown]
# ### Get all Operations for only those Plans

# %%
window_darpa_plan_ids = [p.id for p in window_darpa_plans]
window_darpa_plan_associations = session.PlanAssociation.where({"plan_id": window_darpa_plan_ids})
window_darpa_op_ids = [pa.operation_id for pa in window_darpa_plan_associations]
window_darpa_ops = session.Operation.find(window_darpa_op_ids)
print("{} Operations found for {} Plans.".format(len(window_darpa_ops), budget_name))
# Out:
# 3670 Operations found for DARPA Plans.

# %% [markdown]
# ### Select only the Plans for which the last Operation was completed in the window

# %%
plan_data = {}

for plan in window_darpa_plans:
    pas = [pa for pa in window_darpa_plan_associations if pa.plan_id == plan.id]
    op_ids = [pa.operation_id for pa in pas]
    ops = [op for op in window_darpa_ops if op.id in op_ids]
    statuses = set([op.status for op in ops])
    
    # Exclude plans that are not fully errored or done.
    if statuses - {'done', 'error'}:
        continue
        
    # Exclude plans that are only errors.
    if not statuses - {'error'}:
        continue
    
    sorted_ops = sorted(ops, key=lambda x: x.updated_at)
    last_op_updated_at = dateutil.parser.parse(sorted_ops[-1].updated_at)
    
    if last_op_updated_at >= month_start and last_op_updated_at < month_end:
        d = {}
        d["plan"] = plan
        d["ops"] = sorted_ops
        d["error"] = 'error' in statuses
        plan_data[plan.id] = d
        
print("{} completed Plans found that end in the specified month.".format(len(plan_data)))
print("{} Plans have errored Operations.".format(len([p for p in plan_data.values() if p["error"]])))
# Out:
# 83 completed Plans found that end in the specified month.
# 14 Plans have errored Operations.

# %% [markdown]
# ### Get all OperationTypes and Users and put them in dicts for easy access

# %%
all_operation_types = {}
for ot in session.OperationType.all():
    all_operation_types[ot.id] = ot
    
all_users = {}
for user in session.User.all():
    all_users[user.id] = user

# %% [markdown]
# ### Build a table

# %%
headers = [
    "Challenge problem",
    "Use case/Experiment",
    "Researcher",
    "Description",
    "Data volume delivered to TA4 this month (TBs)",
    "Cumulative data volume delivered to TA4 (TB)",
    "Method Development Required?",
    "Strains",
    "Protocol Performed",
    "Date Started",
    "Date Finished",
    "# Sample",
    "Measurement",
    "Data Volume generated (GBs)",
    "Date data delivered to TA4",
    "Data format",
    "Cost",
    "Comments"
]

def get_challenge_problem(ops, all_operation_types):
    op_types = list(set([all_operation_types[op.operation_type_id].name for op in ops]))
    if "Challenge and Label" in op_types:
        return "Protein Design"
    elif "Treat With Zymolyase" in op_types:
        return "Protein Design"
    elif "4. Measure OD and GFP" in op_types:
        return "YeastSTATES"
    
def get_data_stats(plan):

# %%
table_data = []

for id, data in plan_data.items():
    dates = [op.updated_at for op in data["ops"]]
    start = dateutil.parser.parse(min(dates))
    end = dateutil.parser.parse(max(dates))
    
    comments = []
    row = {}
    row["Description"] = data["plan"].name

    row["Date Started"] = start.strftime("%x")
    row["Date Finished"] = end.strftime("%x")

    if not data.get("cost"):
        data["cost"] = data["plan"].estimate_cost()

    row["Cost"] = data["cost"]
    
    row["Researcher"] = all_users[data["plan"].user_id].name

    if data["error"]:
        comments.append("Some errored Operations.")

    row["Challenge problem"] = get_challenge_problem(data["ops"], all_operation_types)
    
    get_data_stats = 

    row["Comments"] = " ".join(comments)
    table_data.append(row)

# %%
df = pd.DataFrame(data=table_data, columns=headers)

# %%
df
# Out:
#    Challenge problem  Use case/Experiment        Researcher  \
# 0     Protein Design                  NaN  Devin Strickland
# 1                NaN                  NaN    Eriberto Lopez
# 2        YeastSTATES                  NaN  Devin Strickland
# 3                NaN                  NaN      Justin Vrana
# 4                NaN                  NaN      Justin Vrana
# 5                NaN                  NaN      Justin Vrana
# 6     Protein Design                  NaN  Devin Strickland
# 7     Protein Design                  NaN  Devin Strickland
# 8                NaN                  NaN       Joe Control
# 9                NaN                  NaN    Samer Halabiya
# 10               NaN                  NaN       Joe Control
# 11               NaN                  NaN    Samer Halabiya
# 12               NaN                  NaN    Eriberto Lopez
# 13               NaN                  NaN    Samer Halabiya
# 14               NaN                  NaN    Eriberto Lopez
# 15    Protein Design                  NaN  Devin Strickland
# 16               NaN                  NaN  Devin Strickland
# 17               NaN                  NaN    Samer Halabiya
# 18               NaN                  NaN       Joe Control
# 19               NaN                  NaN       Joe Control
# 20    Protein Design                  NaN  Devin Strickland
# 21               NaN                  NaN  Devin Strickland
# 22               NaN                  NaN       Joe Control
# 23               NaN                  NaN    Eriberto Lopez
# 24               NaN                  NaN       Joe Control
# 25               NaN                  NaN      Philip Leung
# 26               NaN                  NaN      Philip Leung
# 27               NaN                  NaN      Philip Leung
# 28               NaN                  NaN      Philip Leung
# 23             Aptamer plasmid transfermations 110518
# 24                 Plasmid Assembly Control 11/6/2018
# 25                    Direct Purchase by Philip Leung
# 26                    Direct Purchase by Philip Leung
# 27                    Direct Purchase by Philip Leung
# 28                    Direct Purchase by Philip Leung
# 29                    Direct Purchase by Philip Leung
# 30                    Direct Purchase by Philip Leung
# 31                 Plasmid Assembly Control 11/7/2018
# 32                                   Pour Gels (copy)
# 33  sgCUP1-x_aptamers_TRP_X_pCENK2 alpha pCup1(FL)...
# 34  sgCUP1-x_aptamers_TRP_X_pCENK2 alpha pCup1(FL)...
# 35         Order delta integration Copy Count primers
# 36                 Plasmid Assembly Control 11/9/2018
# 37              Test E.coli Comp Cell Batch 11/9/2018
# 38                     DonorDNA (PERFORMED BY JUSTIN)
# 39                                    KAPA Master Mix
# 40                        Yeast QC Control 11/13/2018
# 41                        longxing_h3_chip_2_ngs_prep
# 42                Plasmid Assembly Control 11/13/2018
# 43                  Make Miniprep of backbone for DOE
# 44                       Make PCR Fragment delta gRNA
# 45                    Make Maxiprep for DOE Integrant
# 46       Test E.coli Comp Cell Batch 11/9/2018 (copy)
# 47                      Make Yeast Comp Cells for DOE
# 48  Test E.coli Comp Cell Batch 11/9/2018 (copy) (...
# 49                        Yeast QC Control 11/14/2018
# 50                Plasmid Assembly Control 11/14/2018
# 51  sgCUP1-x_aptamers_TRP_X_pCENK2 alpha pCup1(FL)...
# 52             UTP1-pGPD-P1G1-yeVenus-G1T1-tCyc1-T1MC
# 53  sgCUP1-x_aptamers_TRP_X_pCENK2 alpha pCup1(FL)...
# 54                Plasmid Assembly Control 11/15/2018
# 55                    Direct Purchase by Philip Leung
# 56                Plasmid Assembly Control 11/16/2018
# 57  sgCUP1-x_aptamers_TRP_X_pCENK2 alpha pCup1(FL)...
# 58                    Direct Purchase by Philip Leung
# 59                    Direct Purchase by Philip Leung
# 60                    Direct Purchase by Philip Leung
# 61                    Direct Purchase by Philip Leung
# 62                          Heat Shock Transformation
# 63             protein purification GFP test on 11/19
# 64                             Yeast QC Control 11/19
# 65                Assemble Plasmid Control 11/19/2018
# 66                       Gibson Batch Test 11/19/2018
# 67             Marker/Homologies for DONOR DNA (copy)
# 68                             SB glycerol stock plan
# 69                                        Check Plate
# 70                               Yeast Glycerol Stock
# 71                        Yeast QC Control 11/20/2018
# 72            Marker/Homologies for DONOR DNA (try 3)
# 73                       Make Library Glycerol Stocks
# 74                     Assemble Plasmid Control 11/26
# 75                                       Order Primer
# 76                             Make Liquid/Agar Media
# 77                              GFP test run on 11/28
# 78                        Yeast QC Control 11/28/2018
# 79                                   seqencing primer
# 80                     Assemble Plasmid Control 11/28
# 81                             Make Liquid/Agar Media
# 82                                      Untitled Plan
#
#     Data volume delivered to TA4 this month (TBs)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN
# 31                                            NaN
# 32                                            NaN
# 33                                            NaN
# 34                                            NaN
# 35                                            NaN
# 36                                            NaN
# 37                                            NaN
# 38                                            NaN
# 39                                            NaN
# 40                                            NaN
# 41                                            NaN
# 42                                            NaN
# 43                                            NaN
# 44                                            NaN
# 45                                            NaN
# 46                                            NaN
# 47                                            NaN
# 48                                            NaN
# 49                                            NaN
# 50                                            NaN
# 51                                            NaN
# 52                                            NaN
# 53                                            NaN
# 54                                            NaN
# 55                                            NaN
# 56                                            NaN
# 57                                            NaN
# 58                                            NaN
# 59                                            NaN
# 60                                            NaN
# 61                                            NaN
# 62                                            NaN
# 63                                            NaN
# 64                                            NaN
# 65                                            NaN
# 66                                            NaN
# 67                                            NaN
# 68                                            NaN
# 69                                            NaN
# 70                                            NaN
# 71                                            NaN
# 72                                            NaN
# 73                                            NaN
# 74                                            NaN
# 75                                            NaN
# 76                                            NaN
# 77                                            NaN
# 78                                            NaN
# 79                                            NaN
# 80                                            NaN
# 81                                            NaN
# 82                                            NaN
#
#     Cumulative data volume delivered to TA4 (TB)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 29                                           NaN
# 30                                           NaN
# 31                                           NaN
# 32                                           NaN
# 33                                           NaN
# 34                                           NaN
# 35                                           NaN
# 36                                           NaN
# 37                                           NaN
# 38                                           NaN
# 39                                           NaN
# 40                                           NaN
# 41                                           NaN
# 42                                           NaN
# 43                                           NaN
# 44                                           NaN
# 45                                           NaN
# 46                                           NaN
# 47                                           NaN
# 48                                           NaN
# 49                                           NaN
# 50                                           NaN
# 51                                           NaN
# 52                                           NaN
# 53                                           NaN
# 54                                           NaN
# 55                                           NaN
# 56                                           NaN
# 57                                           NaN
# 58                                           NaN
# 59                                           NaN
# 60                                           NaN
# 61                                           NaN
# 62                                           NaN
# 63                                           NaN
# 64                                           NaN
# 65                                           NaN
# 66                                           NaN
# 67                                           NaN
# 68                                           NaN
# 69                                           NaN
# 70                                           NaN
# 71                                           NaN
# 72                                           NaN
# 73                                           NaN
# 74                                           NaN
# 75                                           NaN
# 76                                           NaN
# 77                                           NaN
# 78                                           NaN
# 79                                           NaN
# 80                                           NaN
# 81                                           NaN
# 82                                           NaN
#
#     Method Development Required?  Strains  Protocol Performed Date Started  \
# 0                            NaN      NaN                 NaN     04/20/18
# 1                            NaN      NaN                 NaN     10/10/18
# 2                            NaN      NaN                 NaN     09/25/18
# 3                            NaN      NaN                 NaN     10/25/18
# 4                            NaN      NaN                 NaN     10/25/18
# 5                            NaN      NaN                 NaN     10/25/18
# 6                            NaN      NaN                 NaN     10/26/18
# 7                            NaN      NaN                 NaN     10/29/18
# 8                            NaN      NaN                 NaN     10/30/18
# 9                            NaN      NaN                 NaN     10/31/18
# 10                           NaN      NaN                 NaN     11/01/18
# 11                           NaN      NaN                 NaN     11/01/18
# 12                           NaN      NaN                 NaN     11/01/18
# 13                           NaN      NaN                 NaN     11/02/18
# 14                           NaN      NaN                 NaN     11/02/18
# 15                           NaN      NaN                 NaN     11/02/18
# 16                           NaN      NaN                 NaN     11/02/18
# 17                           NaN      NaN                 NaN     11/04/18
# 18                           NaN      NaN                 NaN     11/05/18
# 19                           NaN      NaN                 NaN     11/05/18
# 20                           NaN      NaN                 NaN     11/06/18
# 21                           NaN      NaN                 NaN     11/05/18
# 22                           NaN      NaN                 NaN     11/05/18
# 23                           NaN      NaN                 NaN     11/05/18
# 24                           NaN      NaN                 NaN     11/06/18
# 25                           NaN      NaN                 NaN     11/06/18
# 26                           NaN      NaN                 NaN     11/06/18
# 27                           NaN      NaN                 NaN     11/06/18
# 28                           NaN      NaN                 NaN     11/06/18
# 29                           NaN      NaN                 NaN     11/06/18
# 30                           NaN      NaN                 NaN     11/06/18
# 1                          NaN          NaN  244.837484  Some errored ops.
# 2                          NaN          NaN   53.829560  Some errored ops.
# 3                          NaN          NaN  105.025553
# 4                          NaN          NaN  105.025553
# 5                          NaN          NaN  105.025553
# 6                          NaN          NaN    0.000000
# 7                          NaN          NaN   81.434950
# 8                          NaN          NaN   12.541114
# 9                          NaN          NaN    0.000000  Some errored ops.
# 10                         NaN          NaN   12.541114
# 11                         NaN          NaN    0.000000
# 12                         NaN          NaN   41.208032
# 13                         NaN          NaN   47.784000
# 14                         NaN          NaN    6.164136
# 15                         NaN          NaN    0.000000
# 16                         NaN          NaN    0.000000
# 17                         NaN          NaN    6.564097
# 18                         NaN          NaN    2.305447
# 19                         NaN          NaN   12.541114
# 20                         NaN          NaN   81.434950
# 21                         NaN          NaN  121.770452
# 22                         NaN          NaN    2.306904
# 23                         NaN          NaN   42.864703
# 24                         NaN          NaN   12.541114
# 25                         NaN          NaN    7.203438
# 26                         NaN          NaN   18.038460
# 27                         NaN          NaN   76.293129
# 28                         NaN          NaN    2.389200
# 29                         NaN          NaN    3.583800
# 30                         NaN          NaN    3.870504
# 31                         NaN          NaN   12.541114
# 32                         NaN          NaN    0.000000
# 33                         NaN          NaN  121.808392  Some errored ops.
# 34                         NaN          NaN   98.969319  Some errored ops.
# 35                         NaN          NaN   11.954410
# 36                         NaN          NaN   12.541114
# 37                         NaN          NaN    9.085751
# 38                         NaN          NaN   37.686897  Some errored ops.
# 39                         NaN          NaN    0.000000
# 40                         NaN          NaN    2.305447
# 41                         NaN          NaN   81.434950  Some errored ops.
# 42                         NaN          NaN   12.541114
# 43                         NaN          NaN    7.651061
# 44                         NaN          NaN    6.564097
# 45                         NaN          NaN   41.280819
# 46                         NaN          NaN    9.085751
# 47                         NaN          NaN   28.576469
# 48                         NaN          NaN    9.085751
# 49                         NaN          NaN    2.305447
# 50                         NaN          NaN   12.541114
# 51                         NaN          NaN   39.192592  Some errored ops.
# 52                         NaN          NaN    6.564097
# 53                         NaN          NaN   32.276252  Some errored ops.
# 54                         NaN          NaN   12.541114
# 55                         NaN          NaN    6.803247
# 56                         NaN          NaN   12.541114
# 57                         NaN          NaN   32.276252  Some errored ops.
# 58                         NaN          NaN   12.184920
# 59                         NaN          NaN   22.560021
# 60                         NaN          NaN   41.882676
# 61                         NaN          NaN    9.837531
# 62                         NaN          NaN    0.153900
# 63                         NaN          NaN    0.153900
# 64                         NaN          NaN    2.305447
# 65                         NaN          NaN   12.541114
# 66                         NaN          NaN    8.086609
# 67                         NaN          NaN   60.299036  Some errored ops.
# 68                         NaN          NaN    0.000000
# 69                         NaN          NaN    0.153900
# 70                         NaN          NaN   23.121806  Some errored ops.
# 71                         NaN          NaN    2.305447
# 72                         NaN          NaN   60.299036  Some errored ops.
# 73                         NaN          NaN    0.000000
# 74                         NaN          NaN   12.541114
# 75                         NaN          NaN    8.754650
# 76                         NaN          NaN    0.000000
# 77                         NaN          NaN    0.716760
# 78                         NaN          NaN    2.305447
# 79                         NaN          NaN    3.436577
# 80                         NaN          NaN   12.541114
# 81                         NaN          NaN    0.000000
# 82                         NaN          NaN   26.256388  Some errored ops.

# %%
df.to_csv("progress_report.csv", index=False)

# %%
print(window_darpa_plans[-1])
